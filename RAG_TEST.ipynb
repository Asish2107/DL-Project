# %% [markdown]
# ## RAG System Using Llama2 With Hugging Face

# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in ./.venv/lib/python3.9/site-packages (0.3.21)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in ./.venv/lib/python3.9/site-packages (from langchain) (0.3.49)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.7 in ./.venv/lib/python3.9/site-packages (from langchain) (0.3.7)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in ./.venv/lib/python3.9/site-packages (from langchain) (0.3.19)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./.venv/lib/python3.9/site-packages (from langchain) (2.11.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./.venv/lib/python3.9/site-packages (from langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in ./.venv/lib/python3.9/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in ./.venv/lib/python3.9/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in ./.venv/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in ./.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in ./.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain) (4.13.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in ./.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in ./.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: anyio in ./.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain) (3.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)

# %%
# !pip install llama-index-llms-langchain
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting llama-index-llms-langchain
#   Downloading llama_index_llms_langchain-0.6.1-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: langchain>=0.1.7 in ./.venv/lib/python3.9/site-packages (from llama-index-llms-langchain) (0.3.21)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in ./.venv/lib/python3.9/site-packages (from llama-index-llms-langchain) (0.12.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in ./.venv/lib/python3.9/site-packages (from langchain>=0.1.7->llama-index-llms-langchain) (0.3.49)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.7 in ./.venv/lib/python3.9/site-packages (from langchain>=0.1.7->llama-index-llms-langchain) (0.3.7)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in ./.venv/lib/python3.9/site-packages (from langchain>=0.1.7->llama-index-llms-langchain) (0.3.19)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./.venv/lib/python3.9/site-packages (from langchain>=0.1.7->llama-index-llms-langchain) (2.11.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./.venv/lib/python3.9/site-packages (from langchain>=0.1.7->llama-index-llms-langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in ./.venv/lib/python3.9/site-packages (from langchain>=0.1.7->llama-index-llms-langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in ./.venv/lib/python3.9/site-packages (from langchain>=0.1.7->llama-index-llms-langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in ./.venv/lib/python3.9/site-packages (from langchain>=0.1.7->llama-index-llms-langchain) (4.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (3.11.14)
# Requirement already satisfied: banks<3.0.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (2.1.0)
# Requirement already satisfied: dataclasses-json in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (1.0.8)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (0.2.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (2025.3.1)
# Requirement already satisfied: httpx in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (3.2.1)
# Requirement already satisfied: nltk>3.8.1 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (3.9.1)
# Requirement already satisfied: numpy in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (2.0.2)
# Requirement already satisfied: pillow>=9.0.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (11.1.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (4.13.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (0.9.0)
# Requirement already satisfied: wrapt in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (1.18.3)
# Requirement already satisfied: griffe in ./.venv/lib/python3.9/site-packages (from banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (1.7.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (3.1.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain>=0.1.7->llama-index-llms-langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in ./.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain>=0.1.7->llama-index-llms-langchain) (24.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.17->langchain>=0.1.7->llama-index-llms-langchain) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.17->langchain>=0.1.7->llama-index-llms-langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in ./.venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.1.17->langchain>=0.1.7->llama-index-llms-langchain) (0.23.0)
# Requirement already satisfied: anyio in ./.venv/lib/python3.9/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (4.9.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.9/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.9/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (1.0.7)
# Requirement already satisfied: idna in ./.venv/lib/python3.9/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (0.14.0)
# Requirement already satisfied: click in ./.venv/lib/python3.9/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (8.1.8)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.9/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain>=0.1.7->llama-index-llms-langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in ./.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain>=0.1.7->llama-index-llms-langchain) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain>=0.1.7->llama-index-llms-langchain) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain>=0.1.7->llama-index-llms-langchain) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.9/site-packages (from requests<3,>=2->langchain>=0.1.7->llama-index-llms-langchain) (1.26.6)
# Requirement already satisfied: greenlet>=1 in ./.venv/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (3.26.1)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain>=0.1.7->llama-index-llms-langchain) (3.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.9/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (1.3.1)
# Requirement already satisfied: colorama>=0.4 in ./.venv/lib/python3.9/site-packages (from griffe->banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-langchain) (3.0.2)
# Downloading llama_index_llms_langchain-0.6.1-py3-none-any.whl (6.1 kB)
# Installing collected packages: llama-index-llms-langchain
# Successfully installed llama-index-llms-langchain-0.6.1

# %%
# !pip install llama-index-embeddings-langchain
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting llama-index-embeddings-langchain
#   Downloading llama_index_embeddings_langchain-0.3.0-py3-none-any.whl.metadata (661 bytes)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in ./.venv/lib/python3.9/site-packages (from llama-index-embeddings-langchain) (0.12.27)
# Requirement already satisfied: PyYAML>=6.0.1 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in ./.venv/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (2.0.40)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (3.11.14)
# Requirement already satisfied: banks<3.0.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (2.1.0)
# Requirement already satisfied: dataclasses-json in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (1.0.8)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (0.2.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (2025.3.1)
# Requirement already satisfied: httpx in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (3.2.1)
# Requirement already satisfied: nltk>3.8.1 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (3.9.1)
# Requirement already satisfied: numpy in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (2.0.2)
# Requirement already satisfied: pillow>=9.0.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (2.11.1)
# Requirement already satisfied: requests>=2.31.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (4.13.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (0.9.0)
# Requirement already satisfied: wrapt in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (1.18.3)
# Requirement already satisfied: griffe in ./.venv/lib/python3.9/site-packages (from banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (1.7.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (3.1.6)
# Requirement already satisfied: click in ./.venv/lib/python3.9/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (8.1.8)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.9/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.9/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in ./.venv/lib/python3.9/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.9/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in ./.venv/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (3.26.1)
# Requirement already satisfied: anyio in ./.venv/lib/python3.9/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.9/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in ./.venv/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (24.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.9/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (1.3.1)
# Requirement already satisfied: colorama>=0.4 in ./.venv/lib/python3.9/site-packages (from griffe->banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (3.0.2)
# Downloading llama_index_embeddings_langchain-0.3.0-py3-none-any.whl (2.5 kB)
# Installing collected packages: llama-index-embeddings-langchain
# Successfully installed llama-index-embeddings-langchain-0.3.0

# %%
# !pip install llama-index-vector-stores-faiss
# Out:
# Collecting llama-index-vector-stores-faiss
#   Downloading llama_index_vector_stores_faiss-0.3.0-py3-none-any.whl.metadata (658 bytes)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in ./.venv/lib/python3.9/site-packages (from llama-index-vector-stores-faiss) (0.12.27)
# Requirement already satisfied: PyYAML>=6.0.1 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in ./.venv/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.0.40)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.11.14)
# Requirement already satisfied: banks<3.0.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.1.0)
# Requirement already satisfied: dataclasses-json in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.0.8)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.2.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2025.3.1)
# Requirement already satisfied: httpx in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.2.1)
# Requirement already satisfied: nltk>3.8.1 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.9.1)
# Requirement already satisfied: numpy in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.0.2)
# Requirement already satisfied: pillow>=9.0.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.11.1)
# Requirement already satisfied: requests>=2.31.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (4.13.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.9.0)
# Requirement already satisfied: wrapt in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.18.3)
# Requirement already satisfied: griffe in ./.venv/lib/python3.9/site-packages (from banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.7.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.1.6)
# Requirement already satisfied: click in ./.venv/lib/python3.9/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (8.1.8)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.9/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.9/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in ./.venv/lib/python3.9/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.9/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in ./.venv/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.26.1)
# Requirement already satisfied: anyio in ./.venv/lib/python3.9/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (4.9.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.9/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in ./.venv/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (24.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.9/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.3.1)
# Requirement already satisfied: colorama>=0.4 in ./.venv/lib/python3.9/site-packages (from griffe->banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.0.2)
# Downloading llama_index_vector_stores_faiss-0.3.0-py3-none-any.whl (3.9 kB)
# Installing collected packages: llama-index-vector-stores-faiss
# Successfully installed llama-index-vector-stores-faiss-0.3.0

# %%
# !pip install llama-index-embeddings-huggingface
# Out:
# Collecting llama-index-embeddings-huggingface
#   Downloading llama_index_embeddings_huggingface-0.5.2-py3-none-any.whl.metadata (767 bytes)
# Requirement already satisfied: huggingface-hub>=0.19.0 in ./.venv/lib/python3.9/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.30.0)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in ./.venv/lib/python3.9/site-packages (from llama-index-embeddings-huggingface) (0.12.27)
# Requirement already satisfied: sentence-transformers>=2.6.1 in ./.venv/lib/python3.9/site-packages (from llama-index-embeddings-huggingface) (4.0.1)
# Requirement already satisfied: filelock in ./.venv/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2025.3.1)
# Requirement already satisfied: packaging>=20.9 in ./.venv/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.2)
# Requirement already satisfied: requests in ./.venv/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in ./.venv/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.venv/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.13.0)
# Requirement already satisfied: aiohttp in ./.venv/lib/python3.9/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.11.14)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in ./.venv/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2.0.40)
# Requirement already satisfied: banks<3.0.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2.1.0)
# Requirement already satisfied: dataclasses-json in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.0.8)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.2.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.2.0)
# Requirement already satisfied: httpx in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.2.1)
# Requirement already satisfied: nltk>3.8.1 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.9.1)
# Requirement already satisfied: numpy in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2.0.2)
# Requirement already satisfied: pillow>=9.0.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2.11.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: wrapt in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.17.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in ./.venv/lib/python3.9/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.50.3)
# Requirement already satisfied: torch>=1.11.0 in ./.venv/lib/python3.9/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.6.0)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.6.1)
# Requirement already satisfied: scipy in ./.venv/lib/python3.9/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.18.3)
# Requirement already satisfied: griffe in ./.venv/lib/python3.9/site-packages (from banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.7.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.1.6)
# Requirement already satisfied: click in ./.venv/lib/python3.9/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (8.1.8)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.9/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.9/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in ./.venv/lib/python3.9/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.9/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.9/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.9/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.9/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in ./.venv/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.1.1)
# Requirement already satisfied: sympy==1.13.1 in ./.venv/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.9/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in ./.venv/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in ./.venv/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.5.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.26.1)
# Requirement already satisfied: anyio in ./.venv/lib/python3.9/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (4.9.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.9/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.14.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.6.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.9/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: colorama>=0.4 in ./.venv/lib/python3.9/site-packages (from griffe->banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.0.2)
# Downloading llama_index_embeddings_huggingface-0.5.2-py3-none-any.whl (8.9 kB)
# Installing collected packages: llama-index-embeddings-huggingface
# Successfully installed llama-index-embeddings-huggingface-0.5.2

# %%
# !pip install --upgrade llama-index
# Out:
# Requirement already satisfied: llama-index in ./.venv/lib/python3.9/site-packages (0.12.27)
# Requirement already satisfied: llama-index-agent-openai<0.5.0,>=0.4.0 in ./.venv/lib/python3.9/site-packages (from llama-index) (0.4.6)
# Requirement already satisfied: llama-index-cli<0.5.0,>=0.4.1 in ./.venv/lib/python3.9/site-packages (from llama-index) (0.4.1)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.27 in ./.venv/lib/python3.9/site-packages (from llama-index) (0.12.27)
# Requirement already satisfied: llama-index-embeddings-openai<0.4.0,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in ./.venv/lib/python3.9/site-packages (from llama-index) (0.6.9)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from llama-index) (0.3.29)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5.0,>=0.4.0 in ./.venv/lib/python3.9/site-packages (from llama-index) (0.4.3)
# Requirement already satisfied: llama-index-program-openai<0.4.0,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4.0,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5.0,>=0.4.0 in ./.venv/lib/python3.9/site-packages (from llama-index) (0.4.7)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in ./.venv/lib/python3.9/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in ./.venv/lib/python3.9/site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in ./.venv/lib/python3.9/site-packages (from llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.69.0)
# Requirement already satisfied: PyYAML>=6.0.1 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in ./.venv/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.27->llama-index) (2.0.40)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (3.11.14)
# Requirement already satisfied: banks<3.0.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (2.1.0)
# Requirement already satisfied: dataclasses-json in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (1.0.8)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (0.2.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (2025.3.1)
# Requirement already satisfied: httpx in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (3.2.1)
# Requirement already satisfied: numpy in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (2.0.2)
# Requirement already satisfied: pillow>=9.0.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (2.11.1)
# Requirement already satisfied: requests>=2.31.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (4.13.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index) (1.17.2)
# Requirement already satisfied: llama-cloud<0.2.0,>=0.1.13 in ./.venv/lib/python3.9/site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.17)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in ./.venv/lib/python3.9/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (4.13.3)
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.2.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in ./.venv/lib/python3.9/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (5.4.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in ./.venv/lib/python3.9/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in ./.venv/lib/python3.9/site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.4.post1)
# Requirement already satisfied: click in ./.venv/lib/python3.9/site-packages (from nltk>3.8.1->llama-index) (8.1.8)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.9/site-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.27->llama-index) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.27->llama-index) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.27->llama-index) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.27->llama-index) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.27->llama-index) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.27->llama-index) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.27->llama-index) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.27->llama-index) (1.18.3)
# Requirement already satisfied: griffe in ./.venv/lib/python3.9/site-packages (from banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.27->llama-index) (1.7.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.27->llama-index) (3.1.6)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.6)
# Requirement already satisfied: certifi>=2024.7.4 in ./.venv/lib/python3.9/site-packages (from llama-cloud<0.2.0,>=0.1.13->llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (2025.1.31)
# Requirement already satisfied: anyio in ./.venv/lib/python3.9/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.27->llama-index) (4.9.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.9/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.27->llama-index) (1.0.7)
# Requirement already satisfied: idna in ./.venv/lib/python3.9/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.27->llama-index) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.27->llama-index) (0.14.0)
# Requirement already satisfied: llama-cloud-services>=0.6.4 in ./.venv/lib/python3.9/site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.9)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.9/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./.venv/lib/python3.9/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (0.9.0)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.9/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.9/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.27->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in ./.venv/lib/python3.9/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.27->llama-index) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.9/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.27->llama-index) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.27->llama-index) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.27->llama-index) (1.26.6)
# Requirement already satisfied: greenlet>=1 in ./.venv/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.27->llama-index) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.27->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.27->llama-index) (3.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.9/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.9/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2025.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.27->llama-index) (1.2.2)
# Requirement already satisfied: platformdirs<5.0.0,>=4.3.7 in ./.venv/lib/python3.9/site-packages (from llama-cloud-services>=0.6.4->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (4.3.7)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in ./.venv/lib/python3.9/site-packages (from llama-cloud-services>=0.6.4->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (1.1.0)
# Requirement already satisfied: packaging>=17.0 in ./.venv/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.27->llama-index) (24.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (1.17.0)
# Requirement already satisfied: colorama>=0.4 in ./.venv/lib/python3.9/site-packages (from griffe->banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.27->llama-index) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.27->llama-index) (3.0.2)

# %%
# !pip install llama-index faiss-cpu sentence-transformers huggingface_hub torch transformers
# Out:
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.9/site-packages (1.1.0)
# Requirement already satisfied: torch in ./.venv/lib/python3.9/site-packages (2.6.0)
# Requirement already satisfied: faiss-cpu in ./.venv/lib/python3.9/site-packages (1.10.0)
# Requirement already satisfied: sentence-transformers in ./.venv/lib/python3.9/site-packages (4.0.1)
# Requirement already satisfied: huggingface_hub in ./.venv/lib/python3.9/site-packages (0.30.0)
# Requirement already satisfied: llama-index[full] in ./.venv/lib/python3.9/site-packages (0.12.27)
# Requirement already satisfied: filelock in ./.venv/lib/python3.9/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./.venv/lib/python3.9/site-packages (from torch) (4.13.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.9/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.9/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.9/site-packages (from torch) (2025.3.1)
# Requirement already satisfied: sympy==1.13.1 in ./.venv/lib/python3.9/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.9/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in ./.venv/lib/python3.9/site-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in ./.venv/lib/python3.9/site-packages (from faiss-cpu) (24.2)
# WARNING: llama-index 0.12.27 does not provide the extra 'full'
# Requirement already satisfied: llama-index-agent-openai<0.5.0,>=0.4.0 in ./.venv/lib/python3.9/site-packages (from llama-index[full]) (0.4.6)
# Requirement already satisfied: llama-index-cli<0.5.0,>=0.4.1 in ./.venv/lib/python3.9/site-packages (from llama-index[full]) (0.4.1)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.27 in ./.venv/lib/python3.9/site-packages (from llama-index[full]) (0.12.27)
# Requirement already satisfied: llama-index-embeddings-openai<0.4.0,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from llama-index[full]) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in ./.venv/lib/python3.9/site-packages (from llama-index[full]) (0.6.9)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from llama-index[full]) (0.3.29)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5.0,>=0.4.0 in ./.venv/lib/python3.9/site-packages (from llama-index[full]) (0.4.3)
# Requirement already satisfied: llama-index-program-openai<0.4.0,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from llama-index[full]) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4.0,>=0.3.0 in ./.venv/lib/python3.9/site-packages (from llama-index[full]) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5.0,>=0.4.0 in ./.venv/lib/python3.9/site-packages (from llama-index[full]) (0.4.7)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in ./.venv/lib/python3.9/site-packages (from llama-index[full]) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in ./.venv/lib/python3.9/site-packages (from llama-index[full]) (3.9.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in ./.venv/lib/python3.9/site-packages (from sentence-transformers) (4.50.3)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.9/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in ./.venv/lib/python3.9/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: Pillow in ./.venv/lib/python3.9/site-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.9/site-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in ./.venv/lib/python3.9/site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: openai>=1.14.0 in ./.venv/lib/python3.9/site-packages (from llama-index-agent-openai<0.5.0,>=0.4.0->llama-index[full]) (1.69.0)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in ./.venv/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (2.0.40)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (3.11.14)
# Requirement already satisfied: banks<3.0.0,>=2.0.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (2.1.0)
# Requirement already satisfied: dataclasses-json in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (1.0.8)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (0.2.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (1.2.0)
# Requirement already satisfied: httpx in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (1.6.0)
# Requirement already satisfied: pydantic>=2.8.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (2.11.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (0.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (0.9.0)
# Requirement already satisfied: wrapt in ./.venv/lib/python3.9/site-packages (from llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (1.17.2)
# Requirement already satisfied: llama-cloud<0.2.0,>=0.1.13 in ./.venv/lib/python3.9/site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index[full]) (0.1.17)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in ./.venv/lib/python3.9/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index[full]) (4.13.3)
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index[full]) (2.2.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in ./.venv/lib/python3.9/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index[full]) (5.4.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in ./.venv/lib/python3.9/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index[full]) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in ./.venv/lib/python3.9/site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index[full]) (0.6.4.post1)
# Requirement already satisfied: click in ./.venv/lib/python3.9/site-packages (from nltk>3.8.1->llama-index[full]) (8.1.8)
# Requirement already satisfied: joblib in ./.venv/lib/python3.9/site-packages (from nltk>3.8.1->llama-index[full]) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.9/site-packages (from nltk>3.8.1->llama-index[full]) (2024.11.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests->huggingface_hub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.9/site-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.9/site-packages (from requests->huggingface_hub) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.9/site-packages (from requests->huggingface_hub) (2025.1.31)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in ./.venv/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in ./.venv/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.9/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (1.18.3)
# Requirement already satisfied: griffe in ./.venv/lib/python3.9/site-packages (from banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (1.7.1)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5.0,>=0.4.0->llama-index[full]) (2.6)
# Requirement already satisfied: anyio in ./.venv/lib/python3.9/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (4.9.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.9/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (0.14.0)
# Requirement already satisfied: llama-cloud-services>=0.6.4 in ./.venv/lib/python3.9/site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index[full]) (0.6.9)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.9/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index[full]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./.venv/lib/python3.9/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index[full]) (0.9.0)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.9/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index[full]) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.9/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in ./.venv/lib/python3.9/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.9/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (0.4.0)
# Requirement already satisfied: greenlet>=1 in ./.venv/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (3.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.9/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index[full]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index[full]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.9/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index[full]) (2025.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.9/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (1.2.2)
# Requirement already satisfied: platformdirs<5.0.0,>=4.3.7 in ./.venv/lib/python3.9/site-packages (from llama-cloud-services>=0.6.4->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index[full]) (4.3.7)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index[full]) (1.17.0)
# Requirement already satisfied: colorama>=0.4 in ./.venv/lib/python3.9/site-packages (from griffe->banks<3.0.0,>=2.0.0->llama-index-core<0.13.0,>=0.12.27->llama-index[full]) (0.4.6)

# %%
import os
from glob import glob
from typing import List
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.llms import Ollama
from langchain.chains import RetrievalQA
from langchain.embeddings.base import Embeddings
from sentence_transformers import SentenceTransformer
import time

# ======================
# Configuration
# ======================

#ollama serve  # This should be running in the terminal
#ollama pull mistral #Download the model

PDF_FOLDER = "/Users/kasish/Desktop/JGASVEMLKNPR-PROJECT/DL-Project/data"          # Folder containing PDF documents
EMBEDDING_MODEL = "all-MiniLM-L6-v2"  # Free embedding model
LLM_MODEL = "mistral"          # Free LLM (options: mistral, llama2, gemma:2b)
CHUNK_SIZE = 1000              # Text chunk size for processing
CHUNK_OVERLAP = 200            # Overlap between chunks

# ======================
# Custom Embeddings Class
# ======================
class LocalEmbeddings(Embeddings):
    """Free local embeddings using SentenceTransformers"""
    def __init__(self, model_name=EMBEDDING_MODEL):
        self.model = SentenceTransformer(model_name)
    
    def embed_documents(self, texts: List[str]) -> List[List[float]]:
        return self.model.encode(texts).tolist()
    
    def embed_query(self, text: str) -> List[float]:
        return self.model.encode(text).tolist()

# ======================
# Document Processing
# ======================
def load_and_process_documents():
    """Load and split PDF documents with error handling"""
    documents = []
    
    # Get all PDF files in the folder
    pdf_files = glob(os.path.join(PDF_FOLDER, "*.pdf"))
    if not pdf_files:
        raise ValueError(f"No PDF files found in {PDF_FOLDER}")
    
    # Process each PDF
    for pdf_path in pdf_files:
        try:
            loader = PyPDFLoader(pdf_path)
            docs = loader.load()
            # Add source metadata
            for doc in docs:
                doc.metadata["source"] = os.path.basename(pdf_path)
            documents.extend(docs)
        except Exception as e:
            print(f"⚠️ Error loading {pdf_path}: {str(e)}")
            continue
    
    # Split documents into chunks
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=CHUNK_SIZE,
        chunk_overlap=CHUNK_OVERLAP,
        separators=["\n\n", "\n", " ", ""]
    )
    return text_splitter.split_documents(documents)

# ======================
# Ollama Connection Setup
# ======================
def verify_ollama_connection(retries=3, delay=5):
    """Ensure Ollama is running before proceeding"""
    for attempt in range(retries):
        try:
            test_llm = Ollama(model=LLM_MODEL)
            test_llm("test")
            return True
        except Exception as e:
            if attempt < retries - 1:
                print(f"🔌 Connection failed, retrying in {delay} seconds...")
                time.sleep(delay)
            else:
                raise RuntimeError(
                    f"Could not connect to Ollama. Please ensure:\n"
                    f"1. Ollama is installed (brew install ollama)\n"
                    f"2. Service is running (ollama serve)\n"
                    f"3. Model is downloaded (ollama pull {LLM_MODEL})"
                )

# ======================
# Main RAG System
# ======================
def initialize_rag_system():
    # Verify Ollama connection first
    verify_ollama_connection()
    
    # Load and process documents
    chunks = load_and_process_documents()
    
    # Create embeddings and vector store
    embeddings = LocalEmbeddings()
    vector_store = FAISS.from_documents(
        chunks,
        embeddings
    )
    
    # Initialize LLM
    llm = Ollama(
        model=LLM_MODEL,
        temperature=0.3,
        timeout=300  # Increase for large documents
    )
    
    # Create QA chain
    return RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=vector_store.as_retriever(search_kwargs={"k": 3}),
        return_source_documents=True
    )

# ======================
# Interactive Query Loop
# ======================
if __name__ == "__main__":
    # Initialize system
    print("🚀 Initializing RAG system...")
    qa_system = initialize_rag_system()
    print("✅ System ready!")
    
    # Query interface
    print("\nAsk questions about your documents (type 'exit' to quit)")
    while True:
        try:
            query = input("\n❓ Question: ")
            if query.lower() in ['exit', 'quit']:
                break
                
            result = qa_system({"query": query})
            
            print("\n💡 Answer:")
            print(result["result"])
            
            print("\n📚 Sources:")
            sources = {doc.metadata["source"] for doc in result["source_documents"]}
            for source in sources:
                print(f"- {source}")
                
        except KeyboardInterrupt:
            break
        except Exception as e:
            print(f"❌ Error: {str(e)}")
# Out:
# 🚀 Initializing RAG system...
# ✅ System ready!
#
# Ask questions about your documents (type 'exit' to quit)
# /var/folders/f2/9d06r3312h991yzd3dgphlch0000gn/T/ipykernel_28260/2168428652.py:140: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = qa_system({"query": query})
# 💡 Answer:
#  It is generally recommended to consume light, easily digestible foods during the night. Foods like fresh fruits, milk, and dairy products are often suggested. However, it's also important to listen to your body and avoid eating if you feel uncomfortable or full. It's always a good idea to consult with a healthcare professional or a nutritionist for personalized advice.
#
# 📚 Sources:
# - overcoming-nutritional-deficiencies.pdf
#
# 💡 Answer:
#  Foods rich in Vitamin B12 include animal products such as meat (beef, liver, and pork), fish, shellfish, dairy products, and eggs. For vegetarians and vegans, fortified foods like certain plant-based milks, breakfast cereals, and nutritional yeast can be good sources of Vitamin B12. Some fermented foods such as tempeh and fortified soy products also contain small amounts of Vitamin B12. It's important to note that absorption of Vitamin B12 may be reduced in people with certain digestive disorders, so they might need supplementation or fortified foods.
#
# 📚 Sources:
# - Main_nutritional_deficiencies.pdf
# - overcoming-nutritional-deficiencies.pdf
#
# 💡 Answer:
#  To help manage high blood pressure, it's essential to follow a balanced diet and maintain a healthy lifestyle. Here are some suggestions based on the provided context:
#
# 1. Limit your salt intake: Salt can increase blood pressure levels, so try to keep your daily consumption below 5 grams. This might require reducing the amount of processed or junk foods in your diet.
#
# 2. Stay hydrated: Drink plenty of fluids like water, lime juice, coconut water, fruit juices, and lassi. These beverages can help maintain proper hydration levels, which is crucial for overall health. Avoid carbonated sweetened beverages as they are high in empty calories.
#
# 3. Ensure adequate iron intake: Iron deficiency can contribute to anemia, which may further complicate high blood pressure management. Consuming foods rich in iron, such as those fortified with iron or paired with vitamin C (like lime juice) can help prevent anemia.
#
# 4. Regular exercise: Engage in regular physical activity, as it helps lower blood pressure and improves cardiovascular health. Consult a healthcare professional for guidance on the appropriate type and intensity of exercise for your specific condition.
#
# 5. Maintain a healthy weight: If you're overweight or obese, losing excess pounds can help reduce high blood pressure levels. A balanced diet and regular physical activity are key to achieving and maintaining a healthy weight.
#
# 📚 Sources:
# - overcoming-nutritional-deficiencies.pdf
